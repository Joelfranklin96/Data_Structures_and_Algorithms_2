# %%
#Find whether the element is present in array or not using Recursion

# %%
def checkNumber(arr, x):
    
    if arr[0] == x:
        return True
    
    if len(arr) == 1:
        return False
    
    return checkNumber_1(arr[1:],x)

# %%
print(checkNumber([1,4,5,3,6],4))
print(checkNumber([1,4,5,3,6],2))
print(checkNumber([1,4,5,3,6],5))
# Out:
# True
# False
# True

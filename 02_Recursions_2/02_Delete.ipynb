# %%
#Delete character "a" in the given string

# %%
def delete(a):
    
    if len(a) == 0:
        return a
    
    smallOutput = Delete(a[1:])
    
    if a[0] == "a":
        return smallOutput
    else:
        return a[0] + smallOutput

# %%
print(Delete("Jals"))
print(Delete("Clap"))
print(Delete("mlape"))
# Out:
# Jls
# Clp
# mlpe
